# %%
# %matplotlib inline
# Out:
# /home/didi/anaconda3/envs/imagehandler/lib/python3.6/site-packages/matplotlib/font_manager.py:279: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
from skimage.io import imread, imshow, imsave

# %%
img = imread('img.png')

# %%
imshow(img)

# %%
img.shape
# Out:
# (1075, 419)

# %%
img.shape[1]
# Out:
# 419

# %%
from numpy import median

# %%
median(5)
# Out:
# 5.0

# %%
a = [1,2,3,4,5]

# %%
median(a)
# Out:
# 3.0

# %%
a = [1,2,3,4,5,6]

# %%
median(a)
# Out:
# 3.5

# %%
img = imread('tiger-color.png')

# %%
imshow(img)

# %%
img.imshape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-e96f50eecaf4> in <module>()
# ----> 1 img.imshape
#
# AttributeError: 'numpy.ndarray' object has no attribute 'imshape'

# %%
img.shape
# Out:
# (601, 801, 3)

# %%
pixel_x = int((img.shape[0]-1)/2+1)

# %%
pixel_y = int((img.shape[1]-1)/2+1)

# %%
print(pixel_x, pixel_y)
# Out:
# 301 401

# %%
img[pixel_x, pixel_y] = [102, 204, 102]

# %%
imsave('out.png', img)

# %%
img2 = imread('out.png')

# %%
from numpy import array_equal

# %%
array_equal(img[301,301], img2[301,301])
# Out:
# True

# %%
img2[301,301]
# Out:
# array([188, 110,  34], dtype=uint8)

# %%
array_equal(img[301,401], img2[301,401])
# Out:
# True

# %%
img2[301,401]
# Out:
# array([102, 204, 102], dtype=uint8)

# %%
img[301,401]
# Out:
# array([102, 204, 102], dtype=uint8)

# %%
img = imread('tiger-color.png')

# %%
img[301,401]
# Out:
# array([154,  94,  67], dtype=uint8)

# %%
array_equal(img[301,401], img2[301,401])
# Out:
# False

# %%
center_img = img[293:300, 385:400]

# %% [raw]
# imshow(center_img)

# %%
imshow(img)

# %%
img.shape
# Out:
# (601, 801, 3)

# %%
center_img.shape
# Out:
# (7, 15, 3)

# %%
c_img = img[int((img.shape[0]-1)/2-7):int((img.shape[0]-1)/2), int((img.shape[1]-1)/2-15):int((img.shape[1]-1)/2)]

# %%
c_img.shape
# Out:
# (7, 15, 3)

# %%
img.shape[0]//2
# Out:
# 300

# %%
img.shape[0]%2
# Out:
# 1
